# %% [markdown]
# <a href="https://colab.research.google.com/github/gobidze/python_turtle-graf/blob/main/My_day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ssl import SSL_ERROR_WANT_READ
#My day
import numpy as np

#coin
def coin (a = 0, b = 5):
    coin = np.random.randint(a, b)
    coin_bin = coin % 2
    return([coin,coin_bin])

# in mirning coffe and cacke
def morning (coffe, cacke):
    if coffe != True:
        My_day = "Sh...t"
    else:
        My_day = "Nice"
        if cacke is True:
           My_day = "Super"
           cacke = False
    return My_day

# days works
def workday (work_1 = 0, work_2 = 0, work_3 = 0, deadline = 0, fast = 0, very_fast = 0, day =0):
    if work_1 is True and work_2 is True and work_3 is True and fast is True and very_fast is True:
        My_day = "sh...t"
    elif work_1 is True or work_2 is True or work_3 is True:
        My_day = "work_day"
    else:
        My_day = "surep"
        if day > deadline:
            My_day = "FULL SH...T!"
    return My_day

# do youre work
def end_day ( WORKS = [0,0,0], in_time = 0, WORKING=list(),count = 0, lets_do_it = ""):
    for work in WORKS:
        do_it = int(work)
        while do_it != False:
            do_it -= 1
            WORKING.append("WORKING HARD")
            count += 1

        if count // 3  > in_time :
            lets_do_it  = "b...tch !"
        else: 
            lets_do_it = " I’m The Best !"
        WORKS[WORKS.index(work)] = lets_do_it
        WORKING.append("WELL DONE") 
    return (WORKING, WORKS)

# randomise all veribles
print( "My day is begin = beep - beep - beep!!!")
coffe = coin()[1]
cacke = coin()[1]
print(("my coffe is hot ->", coffe ==1), ("my cacke is tasty", cacke == 1), 
      ("My morning is ", morning(coffe, cacke)),  '\n', sep = '\n')

day = coin()[0]
work_1 = coin()[1]
work_2 = coin()[1]
work_3 = coin()[1]
deadline = coin(1,3)[0]
fast = coin()[1]
very_fast = coin()[1]
my_work = ["light", "norm", "norm", "BIG"]

print(("My work is", my_work[work_1+work_2+work_3]),
      ( "My affairs is  ", 
       workday(work_1, work_2, work_3, deadline, fast, very_fast, day)), '\n')

WORKS=[coin()[0] for i in range(3)]
DAY = end_day(WORKS, day) # procesed work day
day_work = DAY[0:1]       # timeline of works
day_result = DAY[1:]      # result of works

shape_dw = np.shape(day_work)
shape_dr = np.shape(day_result)
vert_day_w = np.reshape(day_work,(shape_dw[1],shape_dw[0]))
vert_day_r = np.reshape(day_result,(shape_dr[1],shape_dr[0]))

print("Work in progres ...   ",*np.reshape(day_work,(shape_dw[1],shape_dw[0])), '\n',sep = '\n')
print("Work result ->", *np.reshape(day_result,(shape_dr[1],shape_dr[0])),'\n', sep = '\n')

# My day was , full list of day

the_best = list(vert_day_r).count(" I’m The Best !")

if the_best >= 2:
      res_end_day = " I’m The Best !"
else:
      res_end_day = "b...tch !"

print("My day is end it was a ...", " - ".join( [morning(coffe, cacke),
      workday(work_1, work_2, work_3, deadline, fast, very_fast, day),
      res_end_day]), '\n', "I go to sleep... ",sep = '\n')
# Out:
# My day is begin = beep - beep - beep!!!
# ('my coffe is hot ->', False)
# ('my cacke is tasty', False)
# ('My morning is ', 'Sh...t')
#
#
# ('My work is', 'norm') ('My affairs is  ', 'surep')
#
# Work in progres ...
# ['WELL DONE']
# ['WELL DONE']
# ['WORKING HARD']
# ['WORKING HARD']
# ['WORKING HARD']
# ['WELL DONE']
#
#
# Work result ->
# [' I’m The Best !']
# [' I’m The Best !']
# [' I’m The Best !']
#
#
# My day is end it was a ...
# Sh...t - surep -  I’m The Best !
#
#
# I go to sleep...
